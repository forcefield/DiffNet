# %%
# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['font.size'] = 20
import networkx as nx
import numpy as np
from cvxopt import matrix

import sys
sys.path.insert( 0, '../../')

import diffnet as dn
import graph as gph
from netbfe import *

sij = matrix(np.sqrt(np.load("sij_sym.npy")))

#insert delta with stdev=1 for first s_ii:
delta = sij.size[0] * [np.inf]
fict_delta = [1] + delta[1:]

#minimal graph generation:
n = networkBFEalloc( sij, N=1000, delta=fict_delta)
G = gph.diffnet_to_graph( n)
gph.draw_diffnet_graph( G, widthscale=1e-1, nodescale=5)
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0:  0.0000e+00 -1.1000e+01  2e+03  3e+00  2e+01  1e+00
#  1:  4.1596e+00  2.9899e+00  3e+02  3e-01  2e+00  1e-01
#  2:  7.8393e+00  6.7918e+00  3e+02  4e-01  2e+00  3e-01
#  3:  1.1229e+01  1.1102e+01  4e+01  5e-02  3e-01  7e-02
#  4:  1.1823e+01  1.1803e+01  3e+01  3e-02  1e-01  8e-02
#  5:  1.1859e+01  1.1860e+01  3e+00  3e-03  2e-02  1e-02
#  6:  1.1508e+01  1.1511e+01  3e+00  2e-03  1e-02  1e-02
#  7:  1.1508e+01  1.1511e+01  2e+00  1e-03  7e-03  8e-03
#  8:  1.1408e+01  1.1410e+01  6e-01  3e-04  2e-03  3e-03
#  9:  1.1298e+01  1.1299e+01  4e-01  2e-04  1e-03  2e-03
# 10:  1.1288e+01  1.1288e+01  2e-01  7e-05  4e-04  7e-04
# 11:  1.1265e+01  1.1265e+01  4e-02  2e-05  8e-05  2e-04
# 12:  1.1262e+01  1.1262e+01  7e-03  3e-06  2e-05  3e-05
# 13:  1.1261e+01  1.1261e+01  2e-03  8e-07  4e-06  9e-06
# 14:  1.1261e+01  1.1261e+01  2e-04  8e-08  4e-07  9e-07
# 15:  1.1261e+01  1.1261e+01  6e-05  2e-08  1e-07  3e-07
# 16:  1.1261e+01  1.1261e+01  3e-05  1e-08  6e-08  1e-07
# 17:  1.1261e+01  1.1261e+01  1e-06  5e-10  2e-09  5e-09
# Optimal solution found.
# {0: array([0.06987596, 0.02819742]),
#  1: array([ 0.59746333, -0.18016295]),
#  2: array([-0.41300944,  0.01032677]),
#  3: array([-0.28480243,  0.28512536]),
#  4: array([-0.15666635,  0.6053899 ]),
#  5: array([ 0.3393108 , -0.49603989]),
#  6: array([0.44970797, 0.0470038 ]),
#  7: array([0.53206497, 0.37780336]),
#  8: array([-0.28564302, -0.47490033]),
#  9: array([ 0.01046237, -0.40003966]),
#  10: array([0.14123584, 0.51371975]),
#  'O': array([-1.        , -0.31642354])}
